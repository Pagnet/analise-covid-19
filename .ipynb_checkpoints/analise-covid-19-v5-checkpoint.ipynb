# %%
import datetime as dt
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import seaborn as sns
import warnings

from functools import reduce

# %%
warnings.filterwarnings('ignore')

pd.options.display.max_rows = 300
pd.options.display.max_columns = 50

# %%
capitais = ['centro',
            'rio branco',
            'maceió',
            'maceio'
            'macapá',
            'macapa',
            'manaus',
            'salvador',
            'fortaleza',
            'brasília',
            'brasilia',
            'vitória',
            'vitoria',
            'goiânia',
            'goiania',
            'são luís',
            'sao luis',
            'são luis',
            'são luiz',
            'cuiabá',
            'cuiaba',
            'campo grande',
            'belo horizonte',
            '  belo horizonte',
            'belém',
            'belem',
            'joão pessoa',
            'joao pessoa',
            'curitiba',
            'curitiba ',
            'recife',
            'teresina',
            'rio de janeiro',
            'rio  de janeiro',
            'rio de jeneiro',
            'rj',
            'natal',
            'porto alegre',
            'porto velho',
            'boa vista',
            'florianópolis',
            'florianopolis',
            'são paulo',
            'sao paulo',
            'sao paulo ',
            'são paulo ',
            'aracaju',
            'palmas']

# %%
map_dept = {6: 'VESTUÁRIO',
            8: 'CALÇADOS / BOLSAS / MALAS',
            9: 'CAMA / MESA / BANHO / UTILIDADES DOMÉSTICAS',
            25: 'ARTIGOS',
            36: 'ÓTICA',
            45: 'MÓVEIS'}

# %%
dia_da_semana_dict = {1: 'S', 2: 'T', 3: 'Q', 4: 'Q', 5: 'S', 6: 'S', 7: 'D'}

# %%
def augment_df(df):
    df['mes'] = df['dia'].apply(lambda x: x.month)
    df['dia_da_semana'] = df['dia'].apply(lambda x: x.isoweekday())
    df['semana'] = df['dia'].apply(lambda x: x.isocalendar()[1])

    try:
        df['capital'] = df['cidade'].isin(capitais)
    except:
        pass

    try:
        df['dept_cat'] = df['department_id'].map(map_dept)
    except:
        pass

    return df

# %%
def modify_df(df):
    df['dia_da_semana'] = df['dia_da_semana'].map(dia_da_semana_dict)
    df['mes_mod'] = [1]*28 + [2]*28 + [3]*28
    df['semana_mod'] = np.tile(
        reduce(lambda x, y: x + y, [[i % 5]*7 for i in range(1, 5)]), 3)

    return df

# %%
def get_delta_df(df_diff):
    diff = {}

    delta_11 = df_diff.loc[8, 'tot_venda'] / df_diff.loc[0, 'tot_venda']
    diff['delta_11'] = \
    str(round(100 * (delta_11 - 1), 2)).replace('.', ',') + '%'
    delta_12 = df_diff.loc[9, 'tot_venda'] / df_diff.loc[1, 'tot_venda']
    diff['delta_12'] = \
    str(round(100 * (delta_12 - 1), 2)).replace('.', ',') + '%'
    delta_13 = df_diff.loc[10, 'tot_venda'] / df_diff.loc[2, 'tot_venda']
    diff['delta_13'] = \
    str(round(100 * (delta_13 - 1), 2)).replace('.', ',') + '%'
    delta_14 = df_diff.loc[11, 'tot_venda'] / df_diff.loc[3, 'tot_venda']
    diff['delta_14'] = \
    str(round(100 * (delta_14 - 1), 2)).replace('.', ',') + '%'

    delta_21 = df_diff.loc[8, 'tot_venda'] / df_diff.loc[4, 'tot_venda']
    diff['delta_21'] = \
    str(round(100 * (delta_21 - 1), 2)).replace('.', ',') + '%'
    delta_22 = df_diff.loc[9, 'tot_venda'] / df_diff.loc[5, 'tot_venda']
    diff['delta_22'] = \
    str(round(100 * (delta_22 - 1), 2)).replace('.', ',') + '%'
    delta_23 = df_diff.loc[10, 'tot_venda'] / df_diff.loc[6, 'tot_venda']
    diff['delta_23'] = \
    str(round(100 * (delta_23 - 1), 2)).replace('.', ',') + '%'
    delta_24 = df_diff.loc[11, 'tot_venda'] / df_diff.loc[7, 'tot_venda']
    diff['delta_24'] = \
    str(round(100 * (delta_24 - 1), 2)).replace('.', ',') + '%'

    diff = {k: [v, color_negative_red_charts(v)] for k, v in diff.items()}

    return diff

# %%
def color_negative_red_charts(value):
    if value.startswith('-') and value.endswith('%'):
        color = 'red'
    elif value.endswith('%'):
        color = 'green'
    else:
        color = 'black'

    return color

# %%
def impute_missing_dept(df, n_dept, missing_date):
    df_before = df[df['dia'] < missing_date]
    df_after = df[df['dia'] > missing_date]
    date_missing = dt.datetime.strptime(missing_date, '%Y-%m-%d')
    df_before = df_before.append({'department_id': n_dept,
                                  'dia': date_missing,
                                  'tot_venda': 0,
                                  'mes': date_missing.month,
                                  'dia_da_semana': date_missing.isoweekday(),
                                  'semana': date_missing.isocalendar()[1]},
                                 ignore_index=True)
    df_imputed = pd.concat([df_before, df_after],
                           axis=0).reset_index(drop=True)

    return df_imputed

# %%
def impute_missing_estados(df, state, missing_date):
    ts = ((missing_date - np.datetime64('1970-01-01T00:00:00Z')) / 
          np.timedelta64(1, 's'))
    dia_dt = dt.datetime.utcfromtimestamp(ts)
    df_imputed = df.append({'state': state,
                            'dia': dia_dt,
                            'tot_venda': 0,
                            'mes': dia_dt.month,
                            'dia_da_semana': dia_dt.isoweekday(),
                            'semana': dia_dt.isocalendar()[1]},
                           ignore_index=True)
    
    return df_imputed

# %%
def color_negative_red_tables(value):
    if value.startswith('-') and value.endswith('%'):
        color = 'red'
    elif value.endswith('%'):
        color = 'green'
    else:
        color = 'black'

    return 'color: %s' % color

# %%
# ATUALIZAR ABAIXO ANTES DE GERAR O RELATÓRO!!!

# %% [markdown]
# Períodos:
# 2. $M_{-2} \rightarrow$ 27/01/2020 a 23/02/2020 (28 dias)
# 3. $M_{-1} \rightarrow$ 24/02/2020 a 22/03/2020 (28 dias)
# 4. $M_{0} \rightarrow$ 23/03/2020 a 19/04/2020 (28 dias)

# %%
df = pd.read_csv('data/cielo.csv', parse_dates=['dia']).sort_values(
    'dia').dropna(axis=0).reset_index(drop=True)
df = augment_df(df)

# %%
df_ref = df.copy()
df_0 = df[(df['dia'] >= '2020-01-20') & (df['dia'] <= '2020-02-16')]
dias_0 = pd.DataFrame(df_0['dia'].unique(), columns=['dia'])

# %%
# ATUALIZAR ANTES DE GERAR O RELATÓRO!!!
inicio_mes_corrente, fim_mes_corrente = '2020-03-23', '2020-04-19'
df_3 = df[(df['dia'] >= inicio_mes_corrente) & (df['dia'] <= fim_mes_corrente)]
dias_3 = pd.DataFrame(df_3['dia'].unique(), columns=['dia'])

# ATUALIZAR ANTES DE GERAR O RELATÓRO!!!
inicio_analise, fim_analise = '2020-01-27', '2020-04-19'
df = df[(df['dia'] >= inicio_analise) & (df['dia'] <= fim_analise)]
dias = df['dia'].unique()

# %% [markdown]
# # Brasil

# %%
df_brasil = \
modify_df(
    augment_df(
        pd.DataFrame(df.groupby('dia')['tot_venda'].sum()).reset_index()))

# %%
# df_brasil

# %%
dia_ref_0 = df_brasil.loc[56, 'dia'].strftime('%d/%m')
dia_ref_1 = df_brasil.loc[83, 'dia'].strftime('%d/%m')

# %%
df_diff = \
df_brasil.groupby(['mes_mod', 'semana_mod'])['tot_venda'].sum().reset_index()

# %%
# df_diff

# %%
diff = get_delta_df(df_diff)

# %%
# diff

# %%
df_brasil_1 = df_brasil[df_brasil['mes_mod'] == 1].reset_index(drop=True)
df_brasil_2 = df_brasil[df_brasil['mes_mod'] == 2].reset_index(drop=True)
df_brasil_3 = df_brasil[df_brasil['mes_mod'] == 3].reset_index(drop=True)

n_dias = len(df_brasil_1)

fig, ax = plt.subplots(figsize=(20, 4))

sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_brasil_1,
             color='0.6',
             lw=3,
             ax=ax)
sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_brasil_2,
             color='0.4',
             lw=3,
             ax=ax)
sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_brasil_3,
             lw=3,
             ax=ax)

y_max = ax.get_ylim()[1]

ax.set_xlim(-2.5, n_dias)
ax.set_xticks(range(n_dias))
ax.set_xticklabels(df_brasil_1['dia_da_semana'])

ax.axvline(6.5, ymin=0, ymax=200, color='0', ls=':')
ax.axvline(13.5, ymin=0, ymax=200, color='0', ls=':')
ax.axvline(20.5, ymin=0, ymax=200, color='0', ls=':')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.text(0, y_max + 2 * 10**6, '1ª semana', size=15)
ax.text(0,
        y_max + 10**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_11'][0]),
        size=15,
        color=diff['delta_11'][1])
ax.text(0,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_21'][0]),
        size=15,
        color=diff['delta_21'][1])

ax.text(7, y_max + 2 * 10**6, '2ª semana', size=15)
ax.text(7,
        y_max + 10**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_12'][0]),
        size=15,
        color=diff['delta_12'][1])
ax.text(7,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_22'][0]),
        size=15,
        color=diff['delta_22'][1])

ax.text(14, y_max + 2 * 10**6, '3ª semana', size=15)
ax.text(14,
        y_max + 10**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_13'][0]),
        size=15,
        color=diff['delta_13'][1])
ax.text(14,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_23'][0]),
        size=15,
        color=diff['delta_23'][1])

ax.text(21, y_max + 2 * 10**6, '4ª semana', size=15)
ax.text(21,
        y_max + 10**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_14'][0]),
        size=15,
        color=diff['delta_14'][1])
ax.text(21,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_24'][0]),
        size=15,
        color=diff['delta_24'][1])

ax.annotate(f'{dia_ref_0} - 56D',
            (-2.1, df_brasil_1.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_0} - 28D',
            (-2.1, df_brasil_2.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_0}',
            (-1.1, df_brasil_3.loc[0, 'tot_venda']),
            size=12)

ax.annotate(f'{dia_ref_1} - 56D',
            (n_dias-0.9, df_brasil_1.loc[n_dias-1, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1} - 28D',
            (n_dias-0.9, df_brasil_2.loc[n_dias-1, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1}',
            (n_dias-0.9, df_brasil_3.loc[n_dias-1, 'tot_venda']),
            size=12)

ax.set_ylabel('VENDAS TOTAIS', size=12)

plt.savefig('imagens/brasil.png')

# %% [markdown]
# ## Por Departamentos

# %%
df_brasil_dept = \
augment_df(
    pd.DataFrame(
        df.groupby(['department_id', 'dia'])['tot_venda'].sum()).reset_index())

df_brasil_dept_dict = \
{6: df_brasil_dept[df_brasil_dept['department_id'] == 6],
 
 8: (df_brasil_dept[df_brasil_dept['department_id'] == 8]
     .reset_index(drop=True)),
 
 9: (df_brasil_dept[df_brasil_dept['department_id'] == 9]
     .reset_index(drop=True)),
 
 25: (df_brasil_dept[df_brasil_dept['department_id'] == 25]
      .reset_index(drop=True)),
 
 36: (df_brasil_dept[df_brasil_dept['department_id'] == 36]
      .reset_index(drop=True)),
 
 45: (df_brasil_dept[df_brasil_dept['department_id'] == 45]
      .reset_index(drop=True))}

# departamento 6 sem dados para o dia 2020-03-22; imputando tot_venda com 0
df_brasil_dept_dict[6] = \
impute_missing_dept(df_brasil_dept_dict[6], 6, '2020-03-22')

# # departamento 8 sem dados para o dia 2020-03-29; imputando tot_venda com 0
df_brasil_dept_dict[8] = \
impute_missing_dept(df_brasil_dept_dict[8], 8, '2020-03-29')

# # departamento 25 sem dados para o dia 2020-04-12; imputando tot_venda com 0
df_brasil_dept_dict[25] = \
impute_missing_dept(df_brasil_dept_dict[25], 25, '2020-04-12')

df_diff = {}
for d in [6, 8, 9, 25, 36, 45]:
    df_brasil_dept_dict[d] = modify_df(df_brasil_dept_dict[d])
    df_diff[d] = (df_brasil_dept_dict[d]
                  .groupby(['mes_mod', 'semana_mod'])['tot_venda']
                  .sum()
                  .reset_index())

# %%
diff = {d: get_delta_df(df_diff[d]) for d in [6, 8, 9, 25, 36, 45]}

# %%
# diff

# %%
fig, ax = plt.subplots(2, 3, figsize=(30, 8))
loc = [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]

for i, d in enumerate([6, 8, 9, 25, 36, 45]):
    df_brasil_1 = \
    (df_brasil_dept_dict[d][df_brasil_dept_dict[d]['mes_mod'] == 1]
     .reset_index(drop=True))
    df_brasil_2 = \
    (df_brasil_dept_dict[d][df_brasil_dept_dict[d]['mes_mod'] == 2]
     .reset_index(drop=True))
    df_brasil_3 = \
    (df_brasil_dept_dict[d][df_brasil_dept_dict[d]['mes_mod'] == 3]
     .reset_index(drop=True))

    sns.lineplot(x=range(n_dias),
                 y='tot_venda',
                 data=df_brasil_1,
                 color='0.6',
                 lw=3,
                 ax=ax[loc[i]])
    sns.lineplot(x=range(n_dias),
                 y='tot_venda',
                 data=df_brasil_2,
                 color='0.4',
                 lw=3,
                 ax=ax[loc[i]])
    sns.lineplot(x=range(n_dias),
                 y='tot_venda',
                 data=df_brasil_3,
                 lw=3,
                 ax=ax[loc[i]])

    ax[loc[i]].set_title(map_dept[d], pad=20)
    ax[loc[i]].set_xlim(-0.5, n_dias)
    ax[loc[i]].set_xticks(range(n_dias))
    ax[loc[i]].set_xticklabels(df_brasil_1['dia_da_semana'])
    
    ax[loc[i]].axvline(6.5, ymin=0, ymax=200, color='0', ls=':')
    ax[loc[i]].axvline(13.5, ymin=0, ymax=200, color='0', ls=':')
    ax[loc[i]].axvline(20.5, ymin=0, ymax=200, color='0', ls=':')
    
    ax[loc[i]].spines['right'].set_visible(False)
    ax[loc[i]].spines['top'].set_visible(False)
    
    if i in [0, 3]:
        ax[loc[i]].set_ylabel('VENDAS TOTAIS', size=12)
    else:
        ax[loc[i]].set_ylabel('')
        
    ax[loc[i]].annotate(f'{dia_ref_1} - 56D',
                        (n_dias-0.9, df_brasil_1.loc[n_dias-1, 'tot_venda']),
                        size=12)
    ax[loc[i]].annotate(f'{dia_ref_1} - 28D',
                        (n_dias-0.9, df_brasil_2.loc[n_dias-1, 'tot_venda']),
                        size=12)
    ax[loc[i]].annotate(f'{dia_ref_1}',
                        (n_dias-0.9, df_brasil_3.loc[n_dias-1, 'tot_venda']),
                        size=12)

    y_max = ax[loc[i]].get_ylim()[1]
    ax[loc[i]].text(21,
                    y_max,
                    '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(
                        diff[d]['delta_24'][0]),
                    size=12,
                    color=diff[d]['delta_24'][1])

plt.subplots_adjust(wspace=0.3, hspace=0.4)

plt.savefig('imagens/brasil_dept_{}.png'.format(d))

# %% [markdown]
# # Capitais

# %%
df_capitais = \
(pd.DataFrame(df[df['capital'] == True].groupby('dia')['tot_venda'].sum())
 .reset_index())
df_capitais = modify_df(augment_df(df_capitais))

# %%
# df_capitais

# %%
df_diff = (df_capitais.groupby(['mes_mod', 'semana_mod'])['tot_venda']
           .sum()
           .reset_index())

# %%
# df_diff

# %%
diff = get_delta_df(df_diff)

# %%
df_capitais_1 = df_capitais[df_capitais['mes_mod'] == 1].reset_index(drop=True)
df_capitais_2 = df_capitais[df_capitais['mes_mod'] == 2].reset_index(drop=True)
df_capitais_3 = df_capitais[df_capitais['mes_mod'] == 3].reset_index(drop=True)

fig, ax = plt.subplots(figsize=(20, 4))

sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_capitais_1,
             color='0.6',
             lw=3,
             ax=ax)
sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_capitais_2,
             color='0.4',
             lw=3,
             ax=ax)
sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_capitais_3,
             lw=3,
             ax=ax)

y_max = ax.get_ylim()[1]

ax.set_xlim(-2.5, n_dias)
ax.set_xticks(range(n_dias))
ax.set_xticklabels(df_capitais_1['dia_da_semana'])

ax.axvline(6.5, ymin=0, ymax=200, color='0', ls=':')
ax.axvline(13.5, ymin=0, ymax=200, color='0', ls=':')
ax.axvline(20.5, ymin=0, ymax=200, color='0', ls=':')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.text(0, y_max + 2 * 8.75**6, '1ª semana', size=15)
ax.text(0,
        y_max + 8.75**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_11'][0]),
        size=15,
        color=diff['delta_11'][1])
ax.text(0,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_21'][0]),
        size=15,
        color=diff['delta_21'][1])

ax.text(7, y_max + 2 * 8.75**6, '2ª semana', size=15)
ax.text(7,
        y_max + 8.75**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_12'][0]),
        size=15,
        color=diff['delta_12'][1])
ax.text(7,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_22'][0]),
        size=15,
        color=diff['delta_22'][1])

ax.text(14, y_max + 2 * 8.75**6, '3ª semana', size=15)
ax.text(14,
        y_max + 8.75**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_13'][0]),
        size=15,
        color=diff['delta_13'][1])
ax.text(14,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_23'][0]),
        size=15,
        color=diff['delta_23'][1])

ax.text(21, y_max + 2 * 8.75**6, '4ª semana', size=15)
ax.text(21,
        y_max + 8.75**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_14'][0]),
        size=15,
        color=diff['delta_14'][1])
ax.text(21,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_24'][0]),
        size=15,
        color=diff['delta_24'][1])

ax.set_ylabel('VENDAS TOTAIS', size=12)

ax.annotate(f'{dia_ref_0} - 56D',
            (-2.1, df_capitais_1.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_0} - 28D',
            (-2.1, df_capitais_2.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_0}',
            (-1.1, df_capitais_3.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1} - 56D',
            (n_dias-0.9, df_capitais_1.loc[n_dias-1, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1} - 28D',
            (n_dias-0.9, df_capitais_2.loc[n_dias-1, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1}',
            (n_dias-0.9, df_capitais_3.loc[n_dias-1, 'tot_venda']),
            size=12)

plt.savefig('imagens/capitais.png')

# %% [markdown]
# # Não-Capitais

# %%
df_nao_capitais = \
(pd.DataFrame(df[df['capital'] == False].groupby('dia')['tot_venda'].sum())
 .reset_index())

df_nao_capitais = modify_df(augment_df(df_nao_capitais))

# %%
# df_nao_capitais

# %%
df_diff = (df_nao_capitais.groupby(['mes_mod', 'semana_mod'])['tot_venda']
           .sum()
           .reset_index())

# %%
# df_diff

# %%
diff = get_delta_df(df_diff)

# %%
# diff

# %%
df_nao_capitais_1 = \
df_nao_capitais[df_nao_capitais['mes_mod'] == 1].reset_index(drop=True)
df_nao_capitais_2 = \
df_nao_capitais[df_nao_capitais['mes_mod'] == 2].reset_index(drop=True)
df_nao_capitais_3 = \
df_nao_capitais[df_nao_capitais['mes_mod'] == 3].reset_index(drop=True)

fig, ax = plt.subplots(figsize=(20, 4))

sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_nao_capitais_1,
             color='0.6',
             lw=3,
             ax=ax)
sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_nao_capitais_2,
             color='0.4',
             lw=3,
             ax=ax)
sns.lineplot(x=range(n_dias),
             y='tot_venda',
             data=df_nao_capitais_3,
             lw=3,
             ax=ax)

y_max = ax.get_ylim()[1]

ax.set_xlim(-2.5, n_dias)
ax.set_xticks(range(n_dias))
ax.set_xticklabels(df_nao_capitais_1['dia_da_semana'])

ax.axvline(6.5, ymin=0, ymax=200, color='0', ls=':')
ax.axvline(13.5, ymin=0, ymax=200, color='0', ls=':')
ax.axvline(20.5, ymin=0, ymax=200, color='0', ls=':')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.text(0, y_max + 2 * 9.25**6, '1ª semana', size=15)
ax.text(0,
        y_max + 9.25**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_11'][0]),
        size=15,
        color=diff['delta_11'][1])
ax.text(0,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_21'][0]),
        size=15,
        color=diff['delta_21'][1])

ax.text(7, y_max + 2 * 9.25**6, '2ª semana', size=15)
ax.text(7,
        y_max + 9.25**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_12'][0]),
        size=15,
        color=diff['delta_12'][1])
ax.text(7,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_22'][0]),
        size=15,
        color=diff['delta_22'][1])

ax.text(14, y_max + 2 * 9.25**6, '3ª semana', size=15)
ax.text(14,
        y_max + 9.25**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_13'][0]),
        size=15,
        color=diff['delta_13'][1])
ax.text(14,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_23'][0]),
        size=15,
        color=diff['delta_23'][1])

ax.text(21, y_max + 2 * 9.25**6, '4ª semana', size=15)
ax.text(21,
        y_max + 9.25**6,
        '\u0394\u2098 (M\u2080~M\u208B\u2082) = {}'.format(diff['delta_14'][0]),
        size=15,
        color=diff['delta_14'][1])
ax.text(21,
        y_max,
        '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(diff['delta_24'][0]),
        size=15,
        color=diff['delta_24'][1])

ax.set_ylabel('VENDAS TOTAIS', size=12)

ax.annotate(f'{dia_ref_0} - 56D',
            (-2.1, df_nao_capitais_1.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_0} - 28D',
            (-2.1, df_nao_capitais_2.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_0}',
            (-1.1, df_nao_capitais_3.loc[0, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1} - 56D',
            (n_dias-0.9, df_nao_capitais_1.loc[n_dias-1, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1} - 28D',
            (n_dias-0.9, df_nao_capitais_2.loc[n_dias-1, 'tot_venda']),
            size=12)
ax.annotate(f'{dia_ref_1}',
            (n_dias-0.9, df_nao_capitais_3.loc[n_dias-1, 'tot_venda']),
            size=12)

plt.savefig('imagens/nao_capitais.png')

# %% [markdown]
# # Estados

# %%
df = df.dropna(axis=0, subset=['state']).reset_index(drop=True)

# %%
to_replace = ['santa catarina',
              'bahia',
              'sao paulo', 'são pauo', 'são paulo', 'guaruja',
              'alagoas',
              'goias',
              'espírito santo',
              'minas gerais', 'belo horizonte',
              'maranhao',
              'vitoria',
              'rio de janeiro',
              'parana', 'paraná',
              'pará',
              'ceará', 'fortaleza']

estados_dict = {'santa catarina': 'sc',
                'bahia': 'ba',
                'sao paulo': 'sp',
                'são pauo': 'sp',
                'alagoas': 'al',
                'goias': 'go',
                'espírito santo': 'es',
                'minas gerais': 'mg',
                'maranhao': 'ma',
                'vitoria': 'es',
                'rio de janeiro': 'rj',
                'parana': 'pr',
                'paraná': 'pr',
                'pará': 'pa',
                'são paulo': 'sp',
                'belo horizonte': 'mg',
                'ceará': 'ce',
                'fortaleza': 'ce',
                'guaruja': 'sp'}

# %%
mask = df['state'].isin(to_replace)
df.loc[mask, 'state'] = df.loc[mask, 'state'].map(estados_dict)

# %%
estados = df['state'].unique()

# %%
df_estados = (pd.DataFrame(df.groupby(['state', 'dia'])['tot_venda'].sum())
              .reset_index())

df_estados = augment_df(df_estados)

# %%
df_estados_dict = {}
df_diff = {}
for e in estados:
    df_estados_dict[e] = df_estados[df_estados['state'] == e]
    if len(df_estados_dict[e]) < len(dias):
        for d in dias:
            dias_estado = df_estados_dict[e]['dia'].values
            if d in dias_estado:
                continue
            else:
                df_estados_dict[e] = \
                impute_missing_estados(df_estados_dict[e], e, d)
        df_estados_dict[e] = (df_estados_dict[e].sort_values('dia')
                              .reset_index(drop=True))
    else:
        df_estados_dict[e] = (df_estados[df_estados['state'] == e]
                              .reset_index(drop=True))

    df_estados_dict[e] = modify_df(df_estados_dict[e])

    df_diff[e] = (df_estados_dict[e]
                  .groupby(['mes_mod', 'semana_mod'])['tot_venda']
                  .sum()
                  .reset_index())

# %%
estados_ls = list(df_estados_dict.keys())
diff = {e: get_delta_df(df_diff[e]) for e in estados_ls}

# %%
fig, ax = plt.subplots(27, 1, figsize=(20, 4*40))

for i, e in enumerate(estados_ls):
    df_estados_1 = (df_estados_dict[e][df_estados_dict[e]['mes_mod'] == 1]
                    .reset_index(drop=True))
    df_estados_2 = (df_estados_dict[e][df_estados_dict[e]['mes_mod'] == 2]
                    .reset_index(drop=True))
    df_estados_3 = (df_estados_dict[e][df_estados_dict[e]['mes_mod'] == 3]
                    .reset_index(drop=True))

    sns.lineplot(x=range(n_dias),
                 y='tot_venda',
                 data=df_estados_1,
                 color='0.6',
                 lw=3,
                 ax=ax[i])
    sns.lineplot(x=range(n_dias),
                 y='tot_venda',
                 data=df_estados_2,
                 color='0.4',
                 lw=3,
                 ax=ax[i])
    sns.lineplot(x=range(n_dias),
                 y='tot_venda',
                 data=df_estados_3,
                 lw=3,
                 ax=ax[i])

    ax[i].set_xlim(-2.5, n_dias)
    ax[i].set_xticks(range(n_dias))
    ax[i].set_xticklabels(df_estados_1['dia_da_semana'])
    
    ax[i].axvline(6.5, ymin=0, ymax=200, color='0', ls=':')
    ax[i].axvline(13.5, ymin=0, ymax=200, color='0', ls=':')
    ax[i].axvline(20.5, ymin=0, ymax=200, color='0', ls=':')
    
    ax[i].spines['right'].set_visible(False)
    ax[i].spines['top'].set_visible(False)
    ax[i].set_title(e.upper(), pad=30, size=20)
    
    y_max = ax[i].get_ylim()[1]
    
    ax[i].text(0,
               y_max,
               '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(
                   diff[e]['delta_21'][0]),
               size=15,
               color=diff[e]['delta_21'][1])
    ax[i].text(7,
               y_max,
               '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(
                   diff[e]['delta_22'][0]),
               size=15,
               color=diff[e]['delta_22'][1])
    ax[i].text(14,
               y_max,
               '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(
                   diff[e]['delta_23'][0]),
               size=15,
               color=diff[e]['delta_23'][1])
    ax[i].text(21,
               y_max,
               '\u0394\u2098 (M\u2080~M\u208B\u2081) = {}'.format(
                   diff[e]['delta_24'][0]),
               size=15,
               color=diff[e]['delta_24'][1])
    
    ax[i].set_ylabel('VENDAS TOTAIS', size=12)
    
    ax[i].annotate(f'{dia_ref_0} - 56D',
                   (-2.1, df_estados_1.loc[0, 'tot_venda']),
                   size=12)
    ax[i].annotate(f'{dia_ref_0} - 28D',
                   (-2.1, df_estados_2.loc[0, 'tot_venda']),
                   size=12)
    ax[i].annotate(f'{dia_ref_0}',
                   (-1.1, df_estados_3.loc[0, 'tot_venda']),
                   size=12)
    ax[i].annotate(f'{dia_ref_1} - 56D',
                   (n_dias-0.9, df_estados_1.loc[n_dias-1, 'tot_venda']),
                   size=12)
    ax[i].annotate(f'{dia_ref_1} - 28D',
                   (n_dias-0.9, df_estados_2.loc[n_dias-1, 'tot_venda']),
                   size=12)
    ax[i].annotate(f'{dia_ref_1}',
                   (n_dias-0.9, df_estados_3.loc[n_dias-1, 'tot_venda']),
                   size=12)

plt.subplots_adjust(hspace=.6)

# %% [markdown]
# # Estados x Capitais e Não-Capitais

# %%
estados_relevantes = []  # 1M+ volume de vendas no primeiro mês do período
for e in estados_ls:
    if (df_estados_dict[e]
        .loc[df_estados_dict[e]['dia'].isin(dias_0.squeeze(1)), 'tot_venda']
        .sum() > 10**6):
        estados_relevantes.append(e)

# %%
# estados_relevantes

# %%
df_estados_cpt = (pd.DataFrame(df[df['capital'] == True]
                               .groupby(['state', 'dia'])['tot_venda']
                               .sum())
                  .reset_index())
df_estados_cpt = augment_df(df_estados_cpt)

df_estados_ncpt = (pd.DataFrame(df[df['capital'] == False]
                                .groupby(['state', 'dia'])['tot_venda']
                                .sum())
                   .reset_index())
df_estados_ncpt = augment_df(df_estados_ncpt)

# %%
df_estados_dict = {}
df_diff = {}
for e in estados_relevantes:
    df_estados_dict[e] = {}
    
    df_estados_dict[e]['cpt'] = df_estados_cpt[df_estados_cpt['state'] == e]
    if len(df_estados_dict[e]['cpt']) < len(dias):
        for d in dias:
            dias_cpt = df_estados_dict[e]['cpt']['dia'].values
            if d in dias_cpt:
                continue
            else:
                df_estados_dict[e]['cpt'] = \
                impute_missing_estados(df_estados_dict[e]['cpt'], e, d)
        df_estados_dict[e]['cpt'] = (df_estados_dict[e]['cpt']
                                     .sort_values('dia')
                                     .reset_index(drop=True))
    else:
        df_estados_dict[e]['cpt'] = \
        df_estados_cpt[df_estados_cpt['state'] == e].reset_index(drop=True)
    df_estados_dict[e]['cpt'] = modify_df(df_estados_dict[e]['cpt'])
    
    df_estados_dict[e]['ncpt'] = df_estados_ncpt[df_estados_ncpt['state'] == e]
    if len(df_estados_dict[e]['ncpt']) < len(dias):
        for d in dias:
            dias_ncpt = df_estados_dict[e]['ncpt']['dia'].values
            if d in dias_ncpt:
                continue
            else:
                df_estados_dict[e]['ncpt'] = \
                impute_missing_estados(df_estados_dict[e]['ncpt'], e, d)
        df_estados_dict[e]['ncpt'] = (df_estados_dict[e]['ncpt']
                                     .sort_values('dia')
                                     .reset_index(drop=True))
    else:
        df_estados_dict[e]['ncpt'] = \
        df_estados_ncpt[df_estados_ncpt['state'] == e].reset_index(drop=True)
    df_estados_dict[e]['ncpt'] = modify_df(df_estados_dict[e]['ncpt'])

    df_diff[e] = {}
    df_diff[e]['cpt'] = (df_estados_dict[e]['cpt']
                         .groupby(['mes_mod', 'semana_mod'])['tot_venda']
                         .sum()
                         .reset_index())
    df_diff[e]['ncpt'] = (df_estados_dict[e]['ncpt']
                          .groupby(['mes_mod', 'semana_mod'])['tot_venda']
                          .sum()
                          .reset_index())

# %% [markdown]
# ## Semana($M_{0}$) x Semana($M_{-1}$) e Semana($M_{-2}$)

# %%
diff = {}
for e in estados_relevantes:
    diff[e] = {}
    for loc in ['cpt', 'ncpt']:
        diff[e][loc] = {}
        
        diff[e][loc]['M\u2080/1 ~ M\u208B\u2082/1'] = \
        str(round(100*(df_diff[e][loc].loc[8, 'tot_venda'] / df_diff[e][loc]
                       .loc[0, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'
        diff[e][loc]['M\u2080/2 ~ M\u208B\u2082/2'] = \
        str(round(100*(df_diff[e][loc].loc[9, 'tot_venda'] / df_diff[e][loc]
                       .loc[1, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'
        diff[e][loc]['M\u2080/3 ~ M\u208B\u2082/3'] = \
        str(round(100*(df_diff[e][loc].loc[10, 'tot_venda'] / df_diff[e][loc]
                       .loc[2, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'
        diff[e][loc]['M\u2080/4 ~ M\u208B\u2082/4'] = \
        str(round(100*(df_diff[e]['cpt'].loc[11, 'tot_venda'] / df_diff[e][loc]
                       .loc[3, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'

        diff[e][loc]['M\u2080/1 ~ M\u208B\u2081/1'] = \
        str(round(100*(df_diff[e][loc].loc[8, 'tot_venda'] / df_diff[e][loc]
                       .loc[4, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'
        diff[e][loc]['M\u2080/2 ~ M\u208B\u2081/2'] = \
        str(round(100*(df_diff[e][loc].loc[9, 'tot_venda'] / df_diff[e][loc]
                       .loc[5, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'
        diff[e][loc]['M\u2080/3 ~ M\u208B\u2081/3'] = \
        str(round(100*(df_diff[e][loc].loc[10, 'tot_venda'] / df_diff[e][loc]
                       .loc[6, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'
        diff[e][loc]['M\u2080/4 ~ M\u208B\u2081/4'] = \
        str(round(100*(df_diff[e][loc].loc[11, 'tot_venda'] / df_diff[e][loc]
                       .loc[7, 'tot_venda'] - 1), 2)).replace('.', ',') + '%'

# %%
df_delta = []
for e in estados_relevantes:
    df_delta.append(pd.DataFrame(diff[e]).T)

# %%
# estados_relevantes

# %%
estados = ['ES', 'MG', 'RJ', 'SP',
           'PR', 'RS', 'SC',
           'DF', 'GO', 'MS',
           'AL', 'BA', 'CE', 'MA', 'PB', 'PE', 'RN']

loc = ['cpt', 'ncpt']

regioes = ['SE']*8 + ['S']*6 + ['CO']*6 + ['NE']*14

sorted_index = list(itertools.product(estados, loc))

# %%
df_delta_semanas = pd.concat(df_delta,
                             axis=0,
                             keys=[e.upper() for e in estados_relevantes])
df_delta_semanas.replace(['inf%', 'nan%'], '-', inplace=True)
df_delta_semanas.replace(re.compile('^-?\d{4,},\d{,2}%'), '-', inplace=True)
df_delta_semanas = df_delta_semanas.reindex(sorted_index)
df_delta_semanas.style.applymap(color_negative_red_tables)
# Out:
# <style  type="text/css" >
#     #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col0 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col1 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col2 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col3 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col4 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col5 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col6 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row0_col7 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row1_col0 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row1_col1 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row1_col2 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row9_col4 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row9_col5 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row9_col6 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row9_col7 {
#             color:  green;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col0 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col1 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col2 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col3 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col4 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col5 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col6 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row10_col7 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a9ceef96row11_col0 {
#             color:  red;
#         }    #T_958aa68c_836a_11ea_9d10_3368a

# %% [markdown]
# ## Dia($M_{0}$) x Dia($M_{0}$)-7

# %%
dias_3_split = pd.DataFrame(zip(dias_3.squeeze(1)[:-7], dias_3.squeeze(1)[7:]),
                            columns=['dia_0', 'dia_1'])
diff_dict = {}
diff = []
for e in estados_relevantes:
    df_cpt_3 = \
    (df_estados_dict[e]['cpt'][df_estados_dict[e]['cpt']['mes_mod'] == 3]
     .reset_index(drop=True))
    if len(df_cpt_3) < len(dias_3):
        df_cpt_3 = dias_3.merge(df_cpt_3, on='dia', how='left')
        df_cpt_3.loc[df_cpt_3['state'].isnull(), 'state'] = e
        df_cpt_3.loc[df_cpt_3['tot_venda'].isnull(), 'tot_venda'] = 0
        ts = (df_cpt_3.loc[df_cpt_3['dia_da_semana'].isnull(), 'dia'] - 
              np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's')
        dia_dt = ts.apply(lambda x: dt.datetime.utcfromtimestamp(x))
        df_cpt_3.loc[df_cpt_3['mes'].isnull(), 'mes'] = \
        dia_dt.apply(lambda x: x.month)
        df_cpt_3.loc[df_cpt_3['dia_da_semana'].isnull(), 'dia_da_semana'] = \
        dia_dt.apply(lambda x: x.isoweekday())
        df_cpt_3.loc[df_cpt_3['semana'].isnull(), 'semana'] = \
        dia_dt.apply(lambda x: x.isocalendar()[1])

    df_ncpt_3 = \
    (df_estados_dict[e]['ncpt'][df_estados_dict[e]['ncpt']['mes_mod'] == 3]
     .reset_index(drop=True))
    if len(df_ncpt_3) < len(dias_3):
        df_ncpt_3 = dias_mar.merge(df_ncpt_3, on='dia', how='left')
        df_ncpt_3.loc[df_ncpt_3['state'].isnull(), 'state'] = e
        df_ncpt_3.loc[df_ncpt_3['tot_venda'].isnull(), 'tot_venda'] = 0
        ts = (df_ncpt_3.loc[df_ncpt_3['dia_da_semana'].isnull(), 'dia'] -
              np.datetime64('1970-01-01T00:00:00Z')) / np.timedelta64(1, 's')
        dia_dt = ts.apply(lambda x: dt.datetime.utcfromtimestamp(x))
        df_ncpt_3.loc[df_ncpt_3['mes'].isnull(), 'mes'] = \
        dia_dt.apply(lambda x: x.month)
        df_ncpt_3.loc[df_ncpt_3['dia_da_semana'].isnull(), 'dia_da_semana'] = \
        dia_dt.apply(lambda x: x.isoweekday())
        df_ncpt_3.loc[df_ncpt_3['semana'].isnull(), 'semana'] = \
        dia_dt.apply(lambda x: x.isocalendar()[1])

    diff_dict[e] = []
    for i in range(7):
        df_temp_cpt = df_cpt_3[df_cpt_3.index % 7 == i].reset_index(drop=True)
        df_temp_ncpt = df_ncpt_3[df_ncpt_3.index %
                                 7 == i].reset_index(drop=True)
        diff_ls_cpt = []
        diff_ls_ncpt = []
        for j in range(1, len(df_temp_cpt)):
            (diff_ls_cpt.append(
                str(
                    round(
                        100*(df_temp_cpt.loc[j, 'tot_venda'] / 
                             df_temp_cpt.loc[j-1, 'tot_venda'] - 1), 2))
                .replace('.', ',') + '%'))
            (diff_ls_ncpt.append(
                str(
                    round(
                        100*(df_temp_ncpt.loc[j, 'tot_venda'] / 
                             df_temp_ncpt.loc[j-1, 'tot_venda'] - 1), 2))
                .replace('.', ',') + '%'))
        diff_dict[e] += list(zip(df_temp_cpt.loc[1:len(df_temp_cpt), 'dia'],
                                 diff_ls_cpt,
                                 diff_ls_ncpt))
    (diff.append(
        pd.DataFrame(
            sorted(diff_dict[e], key=lambda x: x[0]),
            columns=['dia', 'cpt', 'ncpt']).drop('dia', axis=1).T))

# %%
df_delta_dias = pd.concat(diff,
                          axis=0,
                          keys=[e.upper() for e in estados_relevantes])

dias = (dias_3_split['dia_0']
        .astype(str).apply(lambda x: x[-5:])
        .str.cat(dias_3_split['dia_1']
                 .astype(str).apply(lambda x: x[-5:]), sep=' ~ '))

df_delta_dias.columns = dias

df_delta_dias.rename_axis('', axis=1, inplace=True)
df_delta_dias.replace(['inf%', 'nan%'], '-', inplace=True)
df_delta_dias.replace(re.compile('^-?\d{4,},\d{,2}%'), '-', inplace=True)
df_delta_dias = df_delta_dias.reindex(sorted_index)
df_delta_dias.style.applymap(color_negative_red_tables)
# Out:
# <style  type="text/css" >
#     #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col0 {
#             color:  black;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col1 {
#             color:  red;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col2 {
#             color:  black;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col3 {
#             color:  black;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col4 {
#             color:  red;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col5 {
#             color:  black;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col6 {
#             color:  black;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col7 {
#             color:  red;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row0_col8 {
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col9 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col10 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col11 {
#             color:  red;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col12 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col13 {
#             color:  red;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col14 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col15 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col16 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col17 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col18 {
#             color:  black;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col19 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row3_col20 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row4_col0 {
#             color:  red;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row4_col1 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row4_col2 {
#             color:  green;
#         }    #T_966bdc7e_836a_11ea_9d10_3368a9ceef96row4

# %% [markdown]
# ## Dia($M_{0}$) x Dia(Jan/Fev)

# %% [markdown]
# ### TPV

# %%
df_0 = df_0[['state', 'dia', 'tot_venda', 'mes', 'capital']]

dias_0_3 = (dias_0['dia'].astype(str).apply(lambda x: x[-5:])
            .str.cat(dias_3['dia'].astype(str)
                     .apply(lambda x: x[-5:]), sep=' ~ '))

# %%
df_cpt_0 = {}
df_ncpt_0 = {}
df_cpt_3 = {}
df_ncpt_3 = {}

for e in estados_relevantes:
    df_cpt_0[e] = (df_0.loc[(df_0['capital'] == True) & (df_0['state'] == e)]
                   .drop(['mes', 'state', 'capital'], axis=1)
                   .groupby('dia').sum()
                   .reset_index())
    df_ncpt_0[e] = (df_0.loc[(df_0['capital'] == False) & (df_0['state'] == e)]
                    .drop(['mes', 'state', 'capital'], axis=1)
                    .groupby('dia').sum()
                    .reset_index())

    df_cpt_0[e] = dias_0.merge(
        df_cpt_0[e][df_cpt_0[e]['dia'].isin(dias_0.squeeze(1))],
        on='dia',
        how='left')
    df_ncpt_0[e] = dias_0.merge(
        df_ncpt_0[e][df_ncpt_0[e]['dia'].isin(dias_0.squeeze(1))],
        on='dia',
        how='left')

    df_cpt_3[e] = dias_3.merge(
        df_estados_dict[e]['cpt'][df_estados_dict[e]['cpt']['mes_mod'] == 3],
        on='dia',
        how='left').reset_index(drop=True).drop(['mes',
                                                 'state',
                                                 'dia_da_semana',
                                                 'semana',
                                                 'mes_mod',
                                                 'semana_mod'], axis=1)
    df_ncpt_3[e] = dias_3.merge(
        df_estados_dict[e]['ncpt'][df_estados_dict[e]['ncpt']['mes_mod'] == 3],
        on='dia',
        how='left').reset_index(drop=True).drop(['mes',
                                                 'state',
                                                 'dia_da_semana',
                                                 'semana',
                                                 'mes_mod',
                                                 'semana_mod'], axis=1)

# %%
df_cpt_0_3 = {}
df_ncpt_0_3 = {}
df_0_3 = {}
for e in estados_relevantes:
    df_cpt_0_3[e] = df_cpt_0[e].merge(df_cpt_3[e],
                                      left_index=True,
                                      right_index=True,
                                      suffixes=('_0', '_3'))
    df_cpt_0_3[e]['cpt'] = (round(100*(df_cpt_0_3[e]['tot_venda_3'] / 
                                       df_cpt_0_3[e]['tot_venda_0'] - 1), 2)
                            .astype(str)
                            .str.replace('.', ',') + '%')
    df_cpt_0_3[e]['dias_0_3'] = dias_0_3
    df_cpt_0_3[e] = df_cpt_0_3[e][['dias_0_3', 'cpt']].set_index('dias_0_3')
    df_cpt_0_3[e].index.rename('', inplace=True)

    df_ncpt_0_3[e] = df_ncpt_0[e].merge(df_ncpt_3[e],
                                        left_index=True,
                                        right_index=True,
                                        suffixes=('_0', '_3'))
    df_ncpt_0_3[e]['ncpt'] = (round(100*(df_ncpt_0_3[e]['tot_venda_3'] / 
                                         df_ncpt_0_3[e]['tot_venda_0'] - 1), 2)
                              .astype(str)
                              .str.replace('.', ',') + '%')
    df_ncpt_0_3[e]['dias_0_3'] = dias_0_3
    df_ncpt_0_3[e] = df_ncpt_0_3[e][['dias_0_3', 'ncpt']].set_index('dias_0_3')
    df_ncpt_0_3[e].index.rename('', inplace=True)
    
    df_0_3[e.upper()] = pd.concat([df_cpt_0_3[e], df_ncpt_0_3[e]], axis=1).T
    df_0_3[e.upper()].rename_axis('', axis=1, inplace=True)
    df_0_3[e.upper()].replace(['inf%', 'nan%'], '-', inplace=True)
    df_0_3[e.upper()].replace(re.compile('^-?\d{4,},\d{,2}%'),
                              '-',
                              inplace=True)

# %%
df_delta_0_3 = pd.concat(df_0_3, axis=0)
df_delta_0_3 = df_delta_0_3.reindex(sorted_index)
df_delta_0_3.style.applymap(color_negative_red_tables)
# Out:
# <style  type="text/css" >
#     #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col0 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col1 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col2 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col3 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col4 {
#             color:  green;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col5 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col6 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col7 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col8 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col9 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row0_col10 {
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col18 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col19 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col20 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col21 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col22 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col23 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col24 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col25 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col26 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row2_col27 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row3_col0 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row3_col1 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row3_col2 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row3_col3 {
#             color:  red;
#         }    #T_97a80e6e_836a_11ea_9d10_3368a9ceef96row3_col4 {
#             color:  red;

# %% [markdown]
# ### Clientes Ativos

# %%
n_ativos_0 = {}
n_ativos_3 = {}
for e in estados_relevantes:
    n_ativos_cpt_0 = []
    n_ativos_cpt_3 = []
    n_ativos_ncpt_0 = []
    n_ativos_ncpt_3 = []
    
    for d in dias_0.squeeze(1):
        n_ativos_cpt_0.append(len(df_ref.loc[
            (df_ref['dia'] > d - dt.timedelta(30)) &
            (df_ref['dia'] <= d) &
            (df_ref['state'] == e) &
            (df_ref['capital'] == True), 'id'].unique()))

        n_ativos_ncpt_0.append(len(df_ref.loc[
            (df_ref['dia'] > d - dt.timedelta(30)) &
            (df_ref['dia'] <= d) &
            (df_ref['state'] == e) &
            (df_ref['capital'] == False), 'id'].unique()))

    n_ativos_cpt_0_df = pd.DataFrame(n_ativos_cpt_0, columns=['cpt'])
    n_ativos_ncpt_0_df = pd.DataFrame(n_ativos_ncpt_0, columns=['ncpt'])
    n_ativos_0[e.upper()] = pd.concat([n_ativos_cpt_0_df, n_ativos_ncpt_0_df],
                                      axis=1)

    for d in dias_3.squeeze(1):
        n_ativos_cpt_3.append(len(df_ref.loc[
            (df_ref['dia'] > d - dt.timedelta(30)) &
            (df_ref['dia'] <= d) &
            (df_ref['state'] == e) &
            (df_ref['capital'] == True), 'id'].unique()))

        n_ativos_ncpt_3.append(len(df_3.loc[
            (df_ref['dia'] > d - dt.timedelta(30)) &
            (df_ref['dia'] <= d) &
            (df_ref['state'] == e) &
            (df_ref['capital'] == False), 'id'].unique()))

    n_ativos_cpt_3_df = pd.DataFrame(n_ativos_cpt_3, columns=['cpt'])
    n_ativos_ncpt_3_df = pd.DataFrame(n_ativos_ncpt_3, columns=['ncpt'])
    n_ativos_3[e.upper()] = pd.concat([n_ativos_cpt_3_df, n_ativos_ncpt_3_df],
                                      axis=1)

# %%
n_ativos_0_df = pd.concat(n_ativos_0, axis=1).T
n_ativos_3_df = pd.concat(n_ativos_3, axis=1).T

# %%
df_delta_clientes_0_3 = (round(100 * (n_ativos_3_df/n_ativos_0_df - 1), 2)
                         .astype(str)
                         .replace('.', ',') + '%')
df_delta_clientes_0_3.replace(['inf%', 'nan%'], '-', inplace=True)
df_delta_clientes_0_3.fillna('-', inplace=True)
df_delta_clientes_0_3.replace(re.compile('^-?\d{6,},\d{,2}%'),
                              '-',
                              inplace=True)

df_delta_clientes_0_3.columns = dias_0_3
df_delta_clientes_0_3.columns.name = ''

# %%
df_delta_clientes_0_3 = df_delta_clientes_0_3.reindex(sorted_index)
df_delta_clientes_0_3.style.applymap(color_negative_red_tables)
# Out:
# <style  type="text/css" >
#     #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col0 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col1 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col2 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col3 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col4 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col5 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col6 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col7 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col8 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col9 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col10 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col11 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col12 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col13 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col14 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col15 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col16 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col17 {
#             color:  green;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col18 {
#             color:  red;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col19 {
#             color:  red;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col20 {
#             color:  red;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col21 {
#             color:  red;
#         }    #T_cf286a00_836a_11ea_9d10_3368a9ceef96row0_col22 {
#             color:  red;
